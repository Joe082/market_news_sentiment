# %%
import pandas as pd
filepath = 'news_data/news_data_preprocessed.csv'  
df = pd.read_csv(filepath)

# %%
import pandas as pd
# !pip install gensim
import gensim
# !pip install tqdm
from tqdm import tqdm
import numpy as np
# !pip install scikit-learn
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error
# !pip install matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install nltk
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
tqdm.pandas()
# Out:
# Requirement already satisfied: gensim in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from gensim) (1.26.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pandas in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (2.1.2)
# Requirement already satisfied: pyfume in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3)
# Requirement already satisfied: simpful in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.11.0)
# Requirement already satisfied: fst-pso in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: six>=1.5 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: miniful in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: tqdm in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: scikit-learn in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: matplotlib in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: nltk in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/ange/opt/anaconda3/envs/nlp/lib/python3.11/site-packages (from nltk) (4.65.0)
# [nltk_data] Downloading package punkt to /Users/ange/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/ange/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### TF-IDF by headline_lammas

# %%
vectorizer_headline = TfidfVectorizer (sublinear_tf=True,
                               max_features=500)

# %%
tfidf_matrix_headline = vectorizer_headline.fit_transform(df['headline_lemmas'])
# Convert TFIDF matrix to DataFrame for easier manipulation
tfidf_df_headline = pd.DataFrame(tfidf_matrix_headline.toarray(), columns=vectorizer_headline.get_feature_names_out())
tfidf_df_headline = pd.concat([df[['pub_date']], tfidf_df_headline], axis=1)

#group_by date
tfidf_df_headline.head()
# Out:
#      pub_date  abortion     abuse  accused       act        ad    afghan  \
# 0  2016-01-01       0.0  0.000000      0.0  0.000000  0.000000  0.000000
# 1  2016-01-02       0.0  0.087578      0.0  0.000000  0.000000  0.000000
# 2  2016-01-03       0.0  0.000000      0.0  0.108664  0.000000  0.000000
# 3  2016-01-04       0.0  0.000000      0.0  0.000000  0.116337  0.053188
# 4  2016-01-05       0.0  0.000000      0.0  0.053684  0.053513  0.051344
#
#         age    agenda       aid  ...     woman      word      work  worker  \
# 0  0.000000  0.000000  0.000000  ...  0.038847  0.049549  0.052411   0.000
# 1  0.000000  0.000000  0.000000  ...  0.048036  0.000000  0.064809   0.000
# 2  0.000000  0.000000  0.000000  ...  0.054533  0.000000  0.073574   0.000
# 3  0.000000  0.050834  0.053349  ...  0.047254  0.074705  0.037654   0.049
# 4  0.049071  0.049071  0.000000  ...  0.026941  0.034363  0.000000   0.000
#
#       world     would  yankee      year      york     young
# 0  0.042372  0.000000     0.0  0.148437  0.129921  0.000000
# 1  0.000000  0.000000     0.0  0.143740  0.047281  0.000000
# 2  0.000000  0.000000     0.0  0.139480  0.090880  0.000000
# 3  0.000000  0.045618     0.0  0.078058  0.057649  0.044994
# 4  0.000000  0.074560     0.0  0.048893  0.078118  0.000000
#
# [5 rows x 501 columns]

# %% [markdown]
# ### TF-IDF by snippet_lammas

# %%
vectorizer_abstract = TfidfVectorizer (sublinear_tf=True,
                              max_features=750)  #we set this number higher tto capture bigger variability of terms in abstract

# %%
tfidf_matrix_abstract = vectorizer_abstract.fit_transform(df['snippet_lemmas'])
# Convert TFIDF matrix to DataFrame for easier manipulation
tfidf_df_abstract = pd.DataFrame(tfidf_matrix_abstract.toarray(), columns=vectorizer_abstract.get_feature_names_out())
tfidf_df_abstract = pd.concat([df[['pub_date']], tfidf_df_abstract], axis=1)
tfidf_df_abstract.head()
# Out:
#      pub_date     abuse  according   account   accused    across       act  \
# 0  2016-01-01  0.000000   0.000000  0.000000  0.000000  0.054369  0.000000
# 1  2016-01-02  0.000000   0.000000  0.051806  0.040171  0.066134  0.000000
# 2  2016-01-03  0.000000   0.057273  0.000000  0.044606  0.043372  0.049480
# 3  2016-01-04  0.000000   0.000000  0.034203  0.000000  0.025788  0.070204
# 4  2016-01-05  0.032244   0.000000  0.032273  0.065300  0.024333  0.072437
#
#      action  activist     actor  ...   working     world     would  writer  \
# 0  0.000000   0.04339  0.064439  ...  0.000000  0.056926  0.040142     0.0
# 1  0.000000   0.00000  0.000000  ...  0.000000  0.049131  0.048829     0.0
# 2  0.000000   0.00000  0.000000  ...  0.080898  0.000000  0.000000     0.0
# 3  0.070259   0.00000  0.000000  ...  0.000000  0.053483  0.045435     0.0
# 4  0.085551   0.00000  0.060522  ...  0.000000  0.043136  0.061044     0.0
#
#      writes  yankee      year       yet      york     young
# 0  0.000000     0.0  0.082521  0.038090  0.076288  0.028930
# 1  0.000000     0.0  0.081259  0.000000  0.067050  0.000000
# 2  0.053107     0.0  0.085508  0.087106  0.031200  0.000000
# 3  0.000000     0.0  0.074502  0.030589  0.031409  0.000000
# 4  0.087771     0.0  0.064825  0.028862  0.057808  0.052312
#
# [5 rows x 751 columns]

# %%
tfidf_df_headline.to_csv("news_data/tfidf_headline.csv", index=False)
tfidf_df_abstract.to_csv("news_data/tfidf_snippet.csv", index=False)
