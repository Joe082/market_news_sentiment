# %%
import pandas as pd

# %%
df = pd.read_csv("news_data/archive_data.csv")

# %%
df
# Out:
#                                                  abstract  \
# 0       President Trump’s aides were delighted that ne...
# 1       The Buckeyes quarterback threw one of his four...
# 2       A personal loss has prompted Eileen Shiffrin t...
# 3       The actor and environmentalist released a stat...
# 4       A blocked pipe caused sewage to back up severa...
# ...                                                   ...
# 242015  Anna Wintour, Condé Nast’s artistic director, ...
# 242016  Microsoft sank a data center on the ocean floo...
# 242017  David Eisenhauer, a freshman charged with abdu...
# 242018  A time-capsule look at how the show as markete...
# 242019  When scores of masked men, many of them gang m...
#
#                                                   web_url  \
# 0       https://www.nytimes.com/2019/11/30/us/politics...
# 1       https://www.nytimes.com/2019/11/30/sports/ncaa...
# 2       https://www.nytimes.com/2019/11/30/sports/skii...
# ...

# %%
chunk_size = 10000  # adjust the chunk size as needed
chunks = pd.read_csv("news_data/archive_data.csv", chunksize=chunk_size)
df = pd.concat(chunks, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/ange/Library/CloudStorage/OneDrive-Personal/Emory/2023 Fall/QTM 340/market_news_sentiment/preprocess.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/ange/Library/CloudStorage/OneDrive-Personal/Emory/2023%20Fall/QTM%20340/market_news_sentiment/preprocess.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> chunk_size = 10000  # adjust the chunk size as needed
# ----> <a href='vscode-notebook-cell:/Users/ange/Library/CloudStorage/OneDrive-Personal/Emory/2023%20Fall/QTM%20340/market_news_sentiment/preprocess.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> chunks = pd.read_csv("news_data/archive_data.csv", chunksize=chunk_size)
# ...
